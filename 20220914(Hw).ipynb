# %%
import matplotlib.pyplot as plt

plt.plot([11,21,31,41,51], 'o')

# %%
x = range(0,50)
y = range(0, 100, 2)
plt.plot(x, y, 'o')

# %%
x = range(0,50) #0부터 50까지 증가(1씩)
y = range(0, 100, 2) #0에서 100까지 2씩 증가
plt.plot(x, y, '*') #별표

# %%
x = range(0,50) #0부터 50까지 증가(1씩)
y = range(0, 100, 2) #0에서 100까지 2씩 증가
plt.plot(x, y, 'ro') #빨간색 점

# %%
x = range(0,50) #0부터 50까지 증가(1씩)
y = range(0, 100, 2) #0에서 100까지 2씩 증가
plt.plot(x, y, '^:y') #삼각형 노랑

# %%
## bar 그래프 그리기
x = range(0,15)
Y =
